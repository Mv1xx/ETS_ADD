# %%
arq = read_csv('./cat_breeds.csv', sep=';')
arq['Breed']


{
    'coluna' : ['valor_linha_1', 'valor_linha_2']
}
# Out:
# 0           Angora
# 1           Angora
# 2           Angora
# 3           Angora
# 4           Angora
#            ...
# 1066    Maine coon
# 1067    Maine coon
# 1068    Maine coon
# 1069    Maine coon
# 1070    Maine coon
# Name: Breed, Length: 1071, dtype: object
