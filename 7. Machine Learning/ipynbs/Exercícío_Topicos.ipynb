# %% [markdown]
# - Redução de dimensionalidade com **PCA**
# - **Seleção de atributos**
# - Otimização com **GridSearchCV**
# - Avaliação com **Cross-Validation**
#
# Dataset: `sklearn.datasets.load_iris()` — 150 amostras, 4 features, 3 classes.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.svm import SVC

# %% [markdown]
# O conjunto de dados Iris está disponível diretamente como parte do scikit-learn. Ele pode ser carregado usando a função load_iris.

# %%
data = load_iris(as_frame=True)

# %% [markdown]
# Cada ponto de dados em cada gráfico de dispersão se refere a uma das 150 flores de íris no conjunto de dados, com a cor indicando seu respectivo tipo (Setosa, Versicolor e Virginica).Já é possível observar um padrão em relação ao tipo Setosa, facilmente identificável por sua sépala curta e larga. Considerando apenas essas duas dimensões, largura e comprimento da sépala, ainda há sobreposição entre os tipos Versicolor e Virginica.
#
# A diagonal do gráfico mostra a distribuição de cada característica. Observamos que a largura e o comprimento da pétala são as características mais discriminantes para os três tipos.

# %%
data.frame["target"] = data.target_names[data.target]
_ = sns.pairplot(data.frame, hue="target")

# %% [markdown]
# Vamos separar os dados em X e y. Exiba o shape dos dois

# %%
X = data.data
y = data.target

X._____, _._______

# %% [markdown]
# Aplique a padronização dos dados.

# %%
from sklearn.preprocessing import _______________
scaler = _____________()
X = _________._____________(X)

# %% [markdown]
# Em seguida separe os dados de treinamento e teste.

# %%
from sklearn.model_selection import train_test_split
_______, _________, _________, ___________ = __________________________________

# %% [markdown]
# Aplique a técnica de PCA escolha o número de componentes.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=_)
X_treinamento_pca = 
X_teste_pca =
X_treinamento_pca

# %% [markdown]
# Faça o treinamento com os dados transformados.

# %%
svm_pca = SVC(kernel=_____, C = __)
svm_pca.___(_________, ___________)

# %%
Exiba a acurácia do modelo com PCA aplicado.

# %%
from sklearn.metrics import ____________
previsoes = svm_pca.__________(_______)
_______________(_______, ________)

# %% [markdown]
# Agora com os dados originais faça seleção dos melhores atributos, para testarmos qual técnica traz o melhor resultado.

# %%
from sklearn.feature_selection import f_classif, SelectKBest

selecao = SelectKBest(_______, k=___)
X_anova = selecao.fit____________(_, _)

# %% [markdown]
# Separe os dados novamente.

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(________, _, test_size=____, random_state=____)

# %%
svm_anova = SVC(kernel=_______, C = ____)
svm_anova.___(________, __________)

# %%
previsoes = svm_anova._______(X_teste)
accuracy_score(_________, previsoes)

# %% [markdown]
# Encontre os melhores parâmetros de treinamento utilizando grid search.

# %%
from sklearn.model_selection import GridSearchCV
parametros = {'C': [__________________],
              'kernel': ['rbf', 'linear', 'poly', 'sigmoid']}

# %%
grid_search = GridSearchCV(estimator=SVC(), param_grid=___________)
grid_search.___(X, y)
melhores_parametros = grid_search.best_______
melhor_resultado = grid_search.best_______
print(melhores_parametros)
print(melhor_resultado)

# %% [markdown]
# Por fim, vamos implementar a validação cruzada para verificar o desempenho geral do algoritmo, já implementando os melhores parâmetros.

# %%
from sklearn.model_selection import cross_val_score, KFold

resultados = []

for i in range(30):

  kfold = KFold(n_splits=10, shuffle=True, random_state=_)

  svm = SVC(kernel = ____, C = ___)
  scores = _________(___, _, _, cv = ____)
  resultados.append(_________)
resultados

# %%
print("Acurácia média geral:", _______________________)

# %% [markdown]
# ## Conclusão
# Compare:
# - PCA + SVM
# - SelectKBest + SVM
# - CV + SVM
#
# Qual teve melhor desempenho? Quantos atributos ou componentes usou?
