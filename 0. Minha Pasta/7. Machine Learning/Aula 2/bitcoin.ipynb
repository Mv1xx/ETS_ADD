# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error

import pandas as pd
import numpy as np
import math 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
bit = pd.read_csv("./csv/coin_Bitcoin.csv", sep=",")
bit
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# 1       144.000000    139.000000  0.000000e+00  1.542813e+09
# 2       139.000000    116.989998  0.000000e+00  1.298955e+09
# 3       116.379997    105.209999  0.000000e+00  1.168517e+09
# 4       106.250000     97.750000  0.000000e+00  1.085995e+09
# ...            ...           ...           ...           ...
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11
#
# [2991 rows x 10 columns]

# %% [markdown]
# Tratamento de dados da nossa tabela de Bitcoin:

# %%
bit.drop('SNo', axis=1, inplace=True) #Index Column
bit.drop('Name', axis=1, inplace=True) #Bitcoin
bit.drop('Symbol', axis=1, inplace=True) #BTC
bit.drop('Date', axis=1, inplace=True) #Date Column

figura = plt.figure(figsize=(10,10)) #tamanho da figura
sns.heatmap(bit.corr(), annot=True, fmt=".4f")  #corr >> correlação; annot >> legenda 
plt.show()

# %%
x = bit.loc[:,['Close', 'Open', 'Marketcap', 'High', 'Low']]
y = bit['Volume']

regLinear = []
regPolinomial = []
regRandomForest = []

# score = np.corrcoef(x, y)[0][1]
# score

# correlacao = x.corr(y)
# correlacao

biX = x.values #.reshape(-1, 1)
biX.shape

x_treino, x_teste, y_treino, y_teste = train_test_split(biX, y.values, test_size=0.2, random_state=42)

# %% [markdown]
# Regressão Linear

# %%
linearRegressorBitcoin = LinearRegression()
linearRegressorBitcoin.fit(x_treino, y_treino)

regLinear.append(linearRegressorBitcoin.score(x_treino, y_treino))
regLinear.append(linearRegressorBitcoin.score(x_teste, y_teste))

previsoes = linearRegressorBitcoin.predict(biX)

# print(previsoes)

# MAE = mean_absolute_error(y_teste, previsoes)
# MSE = mean_squared_error(y_teste, previsoes)
# RMSE = np.sqrt(MSE)

# regLinear.append(MAE, MSE, RMSE)

print(regLinear)
# Out:
# [0.6826684143377482, 0.6903840404070195]

# %% [markdown]
# Regressão Linear + Polinomial

# %%
poly = PolynomialFeatures(degree=2)

x_treino_poly = poly.fit_transform(x_treino)
x_teste_poly = poly.transform(x_teste)

polyLiearRegressorBitcoin = LinearRegression()
polyLiearRegressorBitcoin.fit(x_treino_poly, y_treino)

regPolinomial.append(polyLiearRegressorBitcoin.score(x_treino_poly, y_treino))
regPolinomial.append(polyLiearRegressorBitcoin.score(x_teste_poly, y_teste))

previsoes = polyLiearRegressorBitcoin.predict(x_teste_poly)

print(regPolinomial)
# Out:
# [0.7462095057968101, 0.7737914864597439]

# %% [markdown]
# Regressão Random Forest

# %%
randomForestRegressorBitcoin = RandomForestRegressor(n_estimators=100)
randomForestRegressorBitcoin.fit(x_treino, y_treino)

regRandomForest.append(randomForestRegressorBitcoin.score(x_treino, y_treino))
regRandomForest.append(randomForestRegressorBitcoin.score(x_teste, y_teste))

previsoes = randomForestRegressorBitcoin.predict(x_teste)

print(regRandomForest)
# Out:
# [0.972336686960994, 0.8878152249796464]

# %%
print("-="*30)
print(f"-=-=-REGRESSÃO LINEAR-=-=-\nValor de Treino: {round(regLinear[0]*100, 2)}%\nValor de Teste: {round(regLinear[1]*100, 2)}%\n")
print(f"-=-=-REGRESSÃO POLINOMIAL-=-=-\nValor de Treino: {round(regPolinomial[0]*100, 2)}%\nValor de Teste: {round(regPolinomial[1]*100, 2)}%\n")
print(f"-=-=-REGRESSÃO RANDOM FOREST-=-=-\nValor de Treino: {round(regRandomForest[0]*100, 2)}%\nValor de Teste: {round(regRandomForest[1]*100, 2)}%\n")
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# -=-=-REGRESSÃO LINEAR-=-=-
# Valor de Treino: 68.27%
# Valor de Teste: 69.04%
#
# -=-=-REGRESSÃO POLINOMIAL-=-=-
# Valor de Treino: 74.62%
# Valor de Teste: 77.38%
#
# -=-=-REGRESSÃO RANDOM FOREST-=-=-
# Valor de Treino: 97.23%
# Valor de Teste: 88.78%

# %%
print(f"Valor de intersecção encontrado para o metodo de regressão linear: {linearRegressorBitcoin.intercept_}")
print(f"Valor de intersecção encontrado para o metodo de regressão linear polinomial: {polyLiearRegressorBitcoin.intercept_}")
# Out:
# Valor de intersecção encontrado para o metodo de regressão linear: 3727189541.307392
# Valor de intersecção encontrado para o metodo de regressão linear polinomial: -862146499.2885418

# %%
regressorBitcoin.coef_
# Out:
# array([ 0.00000000e+00,  7.44392108e-06,  7.82878230e-09,  1.46669688e-01,
#         8.01728667e-09,  7.64503423e-09, -8.55252854e-08, -6.89848660e-08,
#        -3.93749485e-05, -1.23101717e-07, -1.31446784e-08, -2.87422341e-07,
#         2.08452471e-06, -2.88916820e-07,  7.50706960e-09,  2.10017611e-12,
#         3.76913001e-06, -7.59983264e-06, -2.63021355e-07, -6.26678016e-08,
#         1.65086422e-09])

# %%
previsoes = regressorBitcoin.predict(biX)
previsoes
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        3.26877748e+10, 3.46415705e+10, 3.44753644e+10])

# %%
grafico = px.scatter(x = biX.ravel(), y = y)
grafico.add_scatter(x = biX.ravel(), y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[567], line 1
# ----> 1 grafico = px.scatter(x = biX.ravel(), y = y)
#       2 grafico.add_scatter(x = biX.ravel(), y = previsoes, name = 'Regressão')
#       3 grafico.show()
#
# File c:\Users\disrct\AppData\Local\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File c:\Users\disrct\AppData\Local\anaconda3\Lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File c:\Users\disrct\AppData\Local\anaconda3\Lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\disrct\AppData\Local\anaconda3\Lib\site-packages\plotly\express\_core.py:1245, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1242         col_name = _check_name_not_reserved(field, reserved_names)
#    1244     if length and len(argument) != length:
# -> 1245         raise ValueError(
#    1246             "All arguments should have the same length. "
#    1247             "The length of argument `%s` is %d, whereas the "
#    1248             "length of  previously-processed arguments %s is %d"
#    1249             % (field, len(argument), str(list(df_output.columns)), length)
#    1250         )
#    1251     df_output[str(col_name)] = to_unindexed_series(argument)
#    1253 # Finally, update argument with column name now that column exists
#
# ValueError: All arguments should have the same length. The length of argument `y` is 2991, whereas the length of  previously-processed arguments ['x'] is 14955

# %%
previsao = regressorBitcoin.predict([[70000]])
print(f"A previsão de quantidades negociadas no dia são de {previsao[0]:.2f}")

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 3)
