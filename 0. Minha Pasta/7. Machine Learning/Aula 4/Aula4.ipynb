# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encontro = pd.read_csv("base_segundo_encontro.csv", encoding="latin-1", sep=";")
print(encontro)
# Out:
#      tempo_conversa_min  risadas  pontos_comuns  nivel_timidez  \
# 0                   112       16              6              0
# 1                   102       13              2             10
# 2                    24        8              2              3
# 3                   116        7              4              0
# 4                    81        1              2              5
# ..                  ...      ...            ...            ...
# 995                 129       19              6              0
# 996                  68       17              5              6
# 997                 137        5              3              7
# 998                 123       10              1             10
# 999                 124        1              8              7
#
#      mensagens_antes  iniciativa_conversa local_encontro momento_da_vida  \
# 0                 45                    8    Restaurante      Estressado
# ...

# %%
x = encontro.iloc[:, 0:8]
y = encontro.iloc[:, 8]

x
# Out:
#      tempo_conversa_min  risadas  pontos_comuns  nivel_timidez  \
# 0                   112       16              6              0
# 1                   102       13              2             10
# 2                    24        8              2              3
# 3                   116        7              4              0
# 4                    81        1              2              5
# ..                  ...      ...            ...            ...
# 995                 129       19              6              0
# 996                  68       17              5              6
# 997                 137        5              3              7
# 998                 123       10              1             10
# 999                 124        1              8              7
#
#      mensagens_antes  iniciativa_conversa local_encontro momento_da_vida
# 0                 45                    8    Restaurante      Estressado
# ...

# %%
labelEncoderLocalEncontro = LabelEncoder()
labelEncoderMomentoVida = LabelEncoder()

x['local_encontro'] = labelEncoderLocalEncontro.fit_transform(x.iloc[:, 6])
x['momento_da_vida'] = labelEncoderMomentoVida.fit_transform(x.iloc[:, 7])

x
# Out:
#      tempo_conversa_min  risadas  pontos_comuns  nivel_timidez  \
# 0                   112       16              6              0
# 1                   102       13              2             10
# 2                    24        8              2              3
# 3                   116        7              4              0
# 4                    81        1              2              5
# ..                  ...      ...            ...            ...
# 995                 129       19              6              0
# 996                  68       17              5              6
# 997                 137        5              3              7
# 998                 123       10              1             10
# 999                 124        1              8              7
#
#      mensagens_antes  iniciativa_conversa  local_encontro  momento_da_vida
# 0                 45                    8               3                1
# ...

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y.values, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 x_treino, x_teste, y_treino, y_teste = train_test_split(x.values, y.values, test_size=0.2, random_state=42)
#
# AttributeError: 'StandardScaler' object has no attribute 'values'
